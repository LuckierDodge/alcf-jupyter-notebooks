# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn import metrics
from tensorflow.python.data import Dataset
pd.options.display.max_columns = 300
pd.options.display.max_rows = 300

# %%
df = pd.read_csv('data/ANL-ALCF-AUTOPERF-MIRA_20190101_20190430.csv', header=0).sample(frac=1)

# %%
# df.dtypes

# %%
selected_features = df[[
#     "MACHINE_NAME",
    "RUN_DATE_ID",
    "MPI_MPI_BSEND_INIT_TOTALCYCLES",
    "MPI_MPI_ALLTOALL_TOTALTIME",
    "MPI_MPI_IBSEND_TOTALBYTES",
    "MPI_MPI_ALLGATHERV_TOTALBYTES",
    "MPI_MPI_SSEND_TOTALCYCLES",
    "MPI_MPI_GATHERV_CALLCOUNT",
    "MPI_MPI_SCAN_CALLCOUNT",
    "MPI_MPI_IRECV_TOTALBYTES",
    "MPI_MPI_SCAN_TOTALCYCLES",
    "HPM_PLASTINDEX",
    "MPI_MPI_BSEND_INIT_TOTALTIME",
    "SYS_CORESPERNODE",
    "MPI_MPI_SEND_INIT_TOTALTIME",
    "MPI_MPI_ALLTOALLV_TOTALBYTES",
#     "MPI_VERSION",
    "MPI_MPI_TESTANY_TOTALCYCLES",
    "MPI_MPI_PROBE_TOTALTIME",
    "MPI_MPI_ISSEND_CALLCOUNT",
    "HPM_PFIRSTINDEX",
    "MPI_MPI_BCAST_TOTALTIME",
    "MPI_MPI_REDUCE_SCATTER_TOTALCYCLES",
    "SYS_VERSION",
    "PROC_VERSION",
    "PROC_ELAPSEDCYCLES",
    "MPI_MPI_IBSEND_CALLCOUNT",
    "MPI_MPI_BCAST_TOTALBYTES",
    "MPI_MPI_SSEND_INIT_CALLCOUNT",
    "MPI_MPI_EXSCAN_TOTALTIME",
    "MPI_MYRANK",
    "PROC_EXECNAME_GENID",
    "MPI_MPI_ALLTOALLW_TOTALTIME",
    "MPI_MPI_TESTSOME_CALLCOUNT",
    "MPI_MPI_STARTALL_CALLCOUNT",
#     "MPI_THREADMODE",
    "HPM_PEVT_LSU_COMMIT_LD_MISSES",
    "MPI_MPI_BUFFER_DETACH_CALLCOUNT",
    "MPI_MPI_BUFFER_ATTACH_CALLCOUNT",
    "MPI_MPI_COMM_RANK_CALLCOUNT",
    "MPI_MPI_TESTSOME_TOTALTIME",
    "MPI_MPI_RSEND_TOTALBYTES",
    "SETTINGS_DISABLE_SYS_ENV",
    "SETTINGS_OUTPUT_SYS_ENV_VAL",
    "PROC_BATCHJOBID",
    "MPI_MPI_SEND_TOTALCYCLES",
    "HPM_PEVT_INST_QFPU_FPGRP1",
    "SETTINGS_DISABLE_ALL_ENV",
    "MPI_MPI_WAIT_TOTALCYCLES",
    "MPI_MPI_WAIT_CALLCOUNT",
    "MPI_MPI_TESTALL_TOTALCYCLES",
    "MPI_MPIIOTIME",
    "MPI_MPI_BARRIER_TOTALCYCLES",
    "PROC_CSJOBID",
    "MPI_MPI_GATHERV_TOTALBYTES",
    "MPI_MPI_SSEND_INIT_TOTALCYCLES",
    "MPI_MPI_SCATTER_TOTALTIME",
    "SETTINGS_DEBUG_LEVEL",
    "PROC_PROCESSHWTHREADS",
    "SETTINGS_VERSION",
    "HPM_L2FIRSTINDEX",
    "MPI_MPI_EXSCAN_TOTALCYCLES",
    "MPI_MPI_ALLREDUCE_TOTALCYCLES",
    "MPI_MPI_START_CALLCOUNT",
    "MPI_MPI_BSEND_INIT_TOTALBYTES",
    "MPI_MPI_ALLGATHER_TOTALTIME",
    "MPI_MPI_IRECV_CALLCOUNT",
    "MPI_MPI_STARTALL_TOTALTIME",
    "MPI_MPI_SCATTER_TOTALBYTES",
    "MPI_MPI_ALLTOALLW_CALLCOUNT",
    "MPI_MPI_ALLTOALL_CALLCOUNT",
    "MPI_MPI_SCAN_TOTALBYTES",
    "MPI_MPI_COMM_SIZE_TOTALTIME",
    "MPI_MPI_SENDRECV_REPLACE_TOTALTIME",
    "MPI_MPI_SEND_INIT_TOTALCYCLES",
    "PROC_DISABLED",
    "MPI_MPI_BCAST_TOTALCYCLES",
    "MPI_MPI_GATHER_TOTALCYCLES",
    "SYS_DISABLED",
    "HPM_PEVT_NW_USER_PP_SENT",
    "MPI_MPI_SENDRECV_TOTALBYTES",
    "MPI_MPI_IPROBE_TOTALTIME",
    "MPI_MPI_TESTANY_TOTALBYTES",
    "MPI_MPI_ALLTOALL_TOTALBYTES",
    "MPI_MPI_REDUCE_TOTALBYTES",
    "MPI_MPI_TESTSOME_TOTALBYTES",
    "MPI_MPI_PROBE_CALLCOUNT",
    "MPI_MPI_BUFFER_ATTACH_TOTALBYTES",
    "MPI_MPI_RSEND_TOTALTIME",
    "HPM_PEVT_L2_STORE_LINE",
    "MPI_MPI_BUFFER_DETACH_TOTALBYTES",
    "MPI_MPI_IPROBE_TOTALCYCLES",
    "MPI_MPI_SENDRECV_REPLACE_TOTALBYTES",
    "MPI_MPI_SENDRECV_CALLCOUNT",
    "MPI_MPI_WAITSOME_TOTALCYCLES",
    "MPI_MPI_BARRIER_TOTALBYTES",
    "MPI_MPI_IRECV_TOTALTIME",
    "SETTINGS_DISABLE_HPM",
    "MPI_MPI_BARRIER_TOTALTIME",
    "MPI_MPI_RECV_TOTALTIME",
    "MPI_MPI_SCATTERV_TOTALTIME",
    "MPI_MPI_SCATTERV_TOTALBYTES",
    "MPI_MPI_SENDRECV_TOTALCYCLES",
    "MPI_MPI_WAIT_TOTALTIME",
    "MPI_MPI_RECV_TOTALCYCLES",
    "MPI_MPI_SCATTER_TOTALCYCLES",
    "PROC_USERNAME_GENID",
    "MPI_DISABLED",
    "MPI_MPI_COMM_SIZE_TOTALCYCLES",
    "SETTINGS_OUTPUT_LOCAL_ENV_VAL",
    "MPI_MPI_SCATTERV_TOTALCYCLES",
    "MPI_MPI_WAITANY_TOTALBYTES",
    "MPI_MPI_SENDRECV_TOTALTIME",
    "MPI_MPI_REDUCE_TOTALCYCLES",
    "MPI_MPI_ISEND_TOTALTIME",
    "MPI_MPI_ALLGATHER_CALLCOUNT",
    "MPI_MPI_RSEND_INIT_TOTALTIME",
    "MPI_MPI_RECV_INIT_CALLCOUNT",
    "SETTINGS_OUTPUT_LOCAL_ENV",
    "MPI_MPI_BSEND_INIT_CALLCOUNT",
    "MPI_MPI_BUFFER_DETACH_TOTALCYCLES",
    "MPI_MPI_RSEND_INIT_TOTALBYTES",
    "MPI_MPI_START_TOTALBYTES",
    "MPI_MPI_ISEND_TOTALBYTES",
    "HPM_VERSION",
    "SETTINGS_DISABLE_SYS",
    "MPI_MPI_PROBE_TOTALBYTES",
    "SYS_HWTHREADSPERCORE",
    "SETTINGS_DISABLE_MPI_ENV",
    "HPM_PEVT_L1P_BAS_MISS",
    "SETTINGS_DEBUG_LEVEL_ENV_VAL",
    "MPI_MPI_SEND_INIT_TOTALBYTES",
    "MPI_MPI_TEST_TOTALCYCLES",
    "MPI_MPI_IRSEND_TOTALCYCLES",
    "SETTINGS_OUTPUT_SYS_ENV",
    "MPI_MPI_WAITALL_TOTALCYCLES",
    "MPI_MPI_SSEND_INIT_TOTALTIME",
    "MPI_MPI_WAITALL_TOTALBYTES",
    "MPI_MPI_RECV_CALLCOUNT",
    "HPM_PEVT_INST_QFPU_ALL",
    "MPI_MPI_ALLREDUCE_CALLCOUNT",
    "MPI_MPI_WAITSOME_CALLCOUNT",
    "MPI_MPI_TESTANY_CALLCOUNT",
    "MPI_MPI_TESTALL_CALLCOUNT",
    "MPI_MPI_BUFFER_ATTACH_TOTALTIME",
    "MPI_MPI_SCATTER_CALLCOUNT",
    "MPI_MPI_GATHERV_TOTALCYCLES",
    "MPI_MPI_RSEND_INIT_CALLCOUNT",
    "MPI_MPI_ALLGATHERV_TOTALCYCLES",
    "MPI_MPI_IBSEND_TOTALTIME",
    "MPI_MPI_BSEND_TOTALBYTES",
    "MPI_MPI_GATHERV_TOTALTIME",
    "MPI_MPI_ISSEND_TOTALBYTES",
    "MPI_MPI_REDUCE_CALLCOUNT",
    "MPI_MPI_TEST_TOTALBYTES",
    "MPI_MPI_SEND_INIT_CALLCOUNT",
    "MPI_MPI_RSEND_INIT_TOTALCYCLES",
    "MPI_MPI_RECV_INIT_TOTALBYTES",
    "HPM_DISABLED",
    "PROC_STOPCYCLE",
    "HPM_STOPCYCLE",
    "MPI_MPI_SCATTERV_CALLCOUNT",
    "SETTINGS_DISABLE_PROC",
    "MPI_MPI_REDUCE_SCATTER_CALLCOUNT",
    "MPI_MPI_ISSEND_TOTALTIME",
    "HPM_NWLASTINDEX",
    "MPI_MPI_GATHER_TOTALBYTES",
    "HPM_PEVT_L2_HITS",
    "MPI_MPI_ALLGATHERV_TOTALTIME",
    "MPI_MPI_BARRIER_CALLCOUNT",
    "MPI_MPI_ALLREDUCE_TOTALTIME",
    "MPI_MPI_SCAN_TOTALTIME",
    "MPI_MPI_IRSEND_TOTALTIME",
    "SETTINGS_OUTPUT_SYS",
    "MPI_MPI_RECV_TOTALBYTES",
    "MPI_MPI_ALLGATHERV_CALLCOUNT",
    "HPM_PEVT_L2_FETCH_LINE",
    "MPI_MPI_WAITALL_CALLCOUNT",
    "MPI_MPI_IPROBE_TOTALBYTES",
    "MPI_MPI_EXSCAN_TOTALBYTES",
    "MPI_MPI_WAITANY_CALLCOUNT",
    "MPI_MPI_SEND_CALLCOUNT",
    "MPI_MPI_BUFFER_DETACH_TOTALTIME",
    "MPI_MPI_ALLTOALLV_TOTALCYCLES",
    "MPI_MPI_REDUCE_TOTALTIME",
    "MPI_MPI_TESTANY_TOTALTIME",
    "MPI_MPI_BCAST_CALLCOUNT",
    "MPI_MPI_SSEND_TOTALTIME",
    "MPI_MPI_ALLTOALL_TOTALCYCLES",
    "MPI_MPI_ISEND_CALLCOUNT",
    "MPI_MPI_WAITALL_TOTALTIME",
    "MPI_MPI_TEST_TOTALTIME",
    "MPI_MPI_SENDRECV_REPLACE_TOTALCYCLES",
    "MPI_MPI_REDUCE_SCATTER_TOTALTIME",
    "HPM_PEVT_INST_XU_ALL",
    "MPI_MPI_IRSEND_TOTALBYTES",
    "MPI_MPI_WAITANY_TOTALCYCLES",
    "SETTINGS_DISABLE_HPM_ENV",
    "MPI_MPI_SSEND_TOTALBYTES",
    "MPI_MPI_TESTALL_TOTALTIME",
    "MPI_MPI_STARTALL_TOTALCYCLES",
    "MPI_MPI_RSEND_CALLCOUNT",
    "MPI_MPI_ALLTOALLV_CALLCOUNT",
    "MPI_MPI_ALLTOALLW_TOTALCYCLES",
    "MPI_MPI_WAITANY_TOTALTIME",
    "MPI_MPI_COMM_SIZE_CALLCOUNT",
    "MPI_MPI_TESTALL_TOTALBYTES",
    "PROC_HEAPMAXUSED",
    "MPI_MPI_ALLTOALLV_TOTALTIME",
    "MPI_MPI_IPROBE_CALLCOUNT",
    "MPI_MPI_TEST_CALLCOUNT",
    "MPI_MPI_IRECV_TOTALCYCLES",
    "PROC_STARTCYCLE",
    "MPI_MPI_TESTSOME_TOTALCYCLES",
    "MPI_MPI_RECV_INIT_TOTALTIME",
    "MPI_MPI_IBSEND_TOTALCYCLES",
    "MPI_MPI_START_TOTALCYCLES",
    "MPI_MPI_SEND_TOTALTIME",
    "SETTINGS_OUTPUT_LOCAL",
    "MPI_MPI_REDUCE_SCATTER_TOTALBYTES",
    "MPI_MPI_BSEND_TOTALTIME",
    "MPI_MPI_SENDRECV_REPLACE_CALLCOUNT",
    "HPM_ELAPSEDTIME",
    "MPI_MPI_BSEND_CALLCOUNT",
    "HPM_ELAPSEDCYCLES",
    "MPI_MPI_GATHER_CALLCOUNT",
    "PROC_ELAPSEDTIME",
    "MPI_MPI_START_TOTALTIME",
    "HPM_PEVT_L2_MISSES",
    "MPI_MPI_ISSEND_TOTALCYCLES",
    "MPI_MPI_COMM_RANK_TOTALCYCLES",
    "MPI_NUMRANKS",
    "MPI_MPI_SSEND_CALLCOUNT",
    "MPI_MPI_BUFFER_ATTACH_TOTALCYCLES",
    "MPI_MPI_EXSCAN_CALLCOUNT",
    "HPM_PEVT_NW_USER_PP_RECV",
    "HPM_PEVT_LSU_COMMIT_CACHEABLE_LDS",
    "MPI_MPI_ALLTOALLW_TOTALBYTES",
    "MPI_MPI_STARTALL_TOTALBYTES",
    "HPM_L2LASTINDEX",
    "MPI_MPI_COMM_RANK_TOTALTIME",
    "MPI_STDMPITIME",
    "SETTINGS_DEBUG_LEVEL_ENV",
    "MPI_MPI_BSEND_TOTALCYCLES",
    "MPI_MPI_GATHER_TOTALTIME",
    "MPI_MPI_WAITSOME_TOTALTIME",
    "MPI_MPI_ALLGATHER_TOTALBYTES",
    "HPM_NWFIRSTINDEX",
    "MPI_MPI_SEND_TOTALBYTES",
    "MPI_MPI_RECV_INIT_TOTALCYCLES",
    "HPM_STARTCYCLE",
    "MPI_MPI_RSEND_TOTALCYCLES",
    "MPI_MPI_PROBE_TOTALCYCLES",
    "SETTINGS_DISABLE_PROC_ENV",
    "MPI_MPI_ALLGATHER_TOTALCYCLES",
#     "AUTOPERF_PROC_NAME",
    "MPI_MPI_WAITSOME_TOTALBYTES",
    "SETTINGS_DISABLE_MPI",
    "MPI_MPI_COMM_SIZE_TOTALBYTES",
    "MPI_MPI_ALLREDUCE_TOTALBYTES",
    "MPI_MPI_IRSEND_CALLCOUNT",
    "PROC_NUMPROCESSESONNODE",
    "MPI_MPI_ISEND_TOTALCYCLES",
    "MPI_MPI_SSEND_INIT_TOTALBYTES",
    "MPI_MPI_WAIT_TOTALBYTES",
    "MPI_MPI_COMM_RANK_TOTALBYTES"
]]
features = selected_features.copy()
#     "PROC_EXECNAME_GENID",
#     "MPI_THREADMODE",
#     "PROC_BATCHJOBID",
#     "AUTOPERF_PROC_NAME",
#     "PROC_USERNAME_GENID",
#     "PROC_CSJOBID",
#     "MACHINE_NAME",

targets = pd.DataFrame()
targets["ProcessID"] = df["PROC_EXECNAME_GENID"]#, "PROC_BATCHJOBID"]]

# %%
# print(targets)

# %%
df_train_examples = features.head(int(df.size * .75))
df_train_targets = targets.head(int(df.size * .75))
df_validate_examples = features.tail(int(df.size * .25)).head(int(df.size * .125))
df_validate_targets = targets.tail(int(df.size * .25)).head(int(df.size * .125))
df_test_examples = features.tail(int(df.size * .125)).tail(int(df.size * .125))
df_test_targets = targets.tail(int(df.size * .25)).tail(int(df.size * .125))

# %%
def my_input_fn(features, targets, batch_size=1, shuffle=True, num_epochs=None):
    """Trains a linear regression model of multiple features.
  
    Args:
      features: pandas DataFrame of features
      targets: pandas DataFrame of targets
      batch_size: Size of batches to be passed to the model
      shuffle: True or False. Whether to shuffle the data.
      num_epochs: Number of epochs for which data should be repeated. None = repeat indefinitely
    Returns:
      Tuple of (features, labels) for next data batch
    """
    # Convert pandas data into a dict of np arrays.
    features = {key:np.array(value) for key,value in dict(features).items()}                                           

    # Construct a dataset, and configure batching/repeating.
    ds = Dataset.from_tensor_slices((features,targets)) # warning: 2GB limit
    ds = ds.batch(batch_size).repeat(num_epochs)

    # Shuffle the data, if specified.
    if shuffle:
      ds = ds.shuffle(10000)

    # Return the next batch of data.
    features, labels = ds.make_one_shot_iterator().get_next()

    return features, labels

# %%
def construct_feature_columns(input_features):
  """Construct the TensorFlow Feature Columns.

  Args:
    input_features: The names of the numerical input features to use.
  Returns:
    A set of feature columns
  """ 
  return set([tf.feature_column.numeric_column(my_feature)
              for my_feature in input_features])

# %%
def train_model(
    learning_rate,
    steps,
    batch_size,
    training_examples,
    training_targets,
    validation_examples,
    validation_targets):
  """Trains a linear regression model of multiple features.
  
  In addition to training, this function also prints training progress information,
  as well as a plot of the training and validation loss over time.
  
  Args:
    learning_rate: A `float`, the learning rate.
    steps: A non-zero `int`, the total number of training steps. A training step
      consists of a forward and backward pass using a single batch.
    batch_size: A non-zero `int`, the batch size.
    training_examples: A `DataFrame` containing one or more columns from
      `california_housing_dataframe` to use as input features for training.
    training_targets: A `DataFrame` containing exactly one column from
      `california_housing_dataframe` to use as target for training.
    validation_examples: A `DataFrame` containing one or more columns from
      `california_housing_dataframe` to use as input features for validation.
    validation_targets: A `DataFrame` containing exactly one column from
      `california_housing_dataframe` to use as target for validation.
      
  Returns:
    A `LinearRegressor` object trained on the training data.
  """

  periods = 10
  steps_per_period = steps / periods
  
  # Create a linear regressor object.
  my_optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
  my_optimizer = tf.contrib.estimator.clip_gradients_by_norm(my_optimizer, 5.0)
  linear_regressor = tf.estimator.LinearRegressor(
      feature_columns=construct_feature_columns(training_examples),
      optimizer=my_optimizer
  )
  
  # Create input functions.
  training_input_fn = lambda: my_input_fn(
      training_examples, 
      training_targets[["ProcessID"]], 
      batch_size=batch_size)
  predict_training_input_fn = lambda: my_input_fn(
      training_examples, 
      training_targets["ProcessID"], 
      num_epochs=1, 
      shuffle=False)
  predict_validation_input_fn = lambda: my_input_fn(
      validation_examples, validation_targets["ProcessID"], 
      num_epochs=1, 
      shuffle=False)

  # Train the model, but do so inside a loop so that we can periodically assess
  # loss metrics.
  print("Training model...")
  print("RMSE (on training data):")
  training_rmse = []
  validation_rmse = []
  for period in range (0, periods):
    # Train the model, starting from the prior state.
    linear_regressor.train(
        input_fn=training_input_fn,
        steps=steps_per_period,
    )
    # Take a break and compute predictions.
    training_predictions = linear_regressor.predict(input_fn=predict_training_input_fn)
    training_predictions = np.array([item['predictions'][0] for item in training_predictions])
    
    validation_predictions = linear_regressor.predict(input_fn=predict_validation_input_fn)
    validation_predictions = np.array([item['predictions'][0] for item in validation_predictions])
    
    
    # Compute training and validation loss.
    training_root_mean_squared_error = math.sqrt(
        metrics.mean_squared_error(training_predictions, training_targets))
    validation_root_mean_squared_error = math.sqrt(
        metrics.mean_squared_error(validation_predictions, validation_targets))
    # Occasionally print the current loss.
    print("  period %02d : %0.2f" % (period, training_root_mean_squared_error))
    # Add the loss metrics from this period to our list.
    training_rmse.append(training_root_mean_squared_error)
    validation_rmse.append(validation_root_mean_squared_error)
  print("Model training finished.")

  # Output a graph of loss metrics over periods.
  plt.ylabel("RMSE")
  plt.xlabel("Periods")
  plt.title("Root Mean Squared Error vs. Periods")
  plt.tight_layout()
  plt.plot(training_rmse, label="training")
  plt.plot(validation_rmse, label="validation")
  plt.legend()

  return linear_regressor

# %%
# %matplotlib inline

linear_regressor = train_model(
    learning_rate=0.00003,
    steps=500,
    batch_size=5,
    training_examples=df_train_examples,
    training_targets=df_train_targets,
    validation_examples=df_validate_examples,
    validation_targets=df_validate_targets)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpg9e89loj
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpg9e89loj', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5d1251dcf8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# Training model...
# RMSE (on training data):
# WARNING:tensorflow:From /home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpg9e89loj/model.ckpt.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# InvalidArgumentError: Found Inf or NaN global norm. : Tensor had Inf values
# 	 [[{{node linear/head/VerifyFinite/CheckNumerics}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-14-f295a1c89362> in <module>
#       8     training_targets=df_train_targets,
#       9     validation_examples=df_validate_examples,
# ---> 10     validation_targets=df_validate_targets)
#
# <ipython-input-13-5f96b2ab21ab> in train_model(learning_rate, steps, batch_size, training_examples, training_targets, validation_examples, validation_targets)
#      66     linear_regressor.train(
#      67         input_fn=training_input_fn,
# ---> 68         steps=steps_per_period,
#      69     )
#      70     # Take a break and compute predictions.
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     356
#     357       saving_listeners = _check_listeners_type(saving_listeners)
# --> 358       loss = self._train_model(input_fn, hooks, saving_listeners)
#     359       logging.info('Loss for final step: %s.', loss)
#     360       return self
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1122       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1123     else:
# -> 1124       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1125
#    1126   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1156       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1157                                              hooks, global_step_tensor,
# -> 1158                                              saving_listeners)
#    1159
#    1160   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1405       any_step_done = False
#    1406       while not mon_sess.should_stop():
# -> 1407         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1408         any_step_done = True
#    1409     if not any_step_done:
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     674                           feed_dict=feed_dict,
#     675                           options=options,
# --> 676                           run_metadata=run_metadata)
#     677
#     678   def run_step_fn(self, step_fn):
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1169                               feed_dict=feed_dict,
#    1170                               options=options,
# -> 1171                               run_metadata=run_metadata)
#    1172       except _PREEMPTION_ERRORS as e:
#    1173         logging.info('An error was raised. This may be due to a preemption in '
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1268         raise six.reraise(*original_exc_info)
#    1269       else:
# -> 1270         raise six.reraise(*original_exc_info)
#    1271
#    1272
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1253   def run(self, *args, **kwargs):
#    1254     try:
# -> 1255       return self._sess.run(*args, **kwargs)
#    1256     except _PREEMPTION_ERRORS:
#    1257       raise
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1325                                   feed_dict=feed_dict,
#    1326                                   options=options,
# -> 1327                                   run_metadata=run_metadata)
#    1328
#    1329     for hook in self._hooks:
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1089
#    1090   def run(self, *args, **kwargs):
# -> 1091     return self._sess.run(*args, **kwargs)
#    1092
#    1093   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# InvalidArgumentError: Found Inf or NaN global norm. : Tensor had Inf values
# 	 [[node linear/head/VerifyFinite/CheckNumerics (defined at /home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/contrib/estimator/python/estimator/extenders.py:134) ]]
#
# Caused by op 'linear/head/VerifyFinite/CheckNumerics', defined at:
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-f295a1c89362>", line 10, in <module>
#     validation_targets=df_validate_targets)
#   File "<ipython-input-13-5f96b2ab21ab>", line 68, in train_model
#     steps=steps_per_period,
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 358, in train
#     loss = self._train_model(input_fn, hooks, saving_listeners)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 1124, in _train_model
#     return self._train_model_default(input_fn, hooks, saving_listeners)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 1154, in _train_model_default
#     features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 1112, in _call_model_fn
#     model_fn_results = self._model_fn(features=features, **kwargs)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/linear.py", line 1187, in _model_fn
#     sparse_combiner=sparse_combiner)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/linear.py", line 540, in _linear_model_fn
#     logits=logits)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/head.py", line 240, in create_estimator_spec
#     regularization_losses))
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/head.py", line 1515, in _create_tpu_estimator_spec
#     global_step=training_util.get_global_step())
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/training/optimizer.py", line 413, in minimize
#     name=name)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/contrib/estimator/python/estimator/extenders.py", line 325, in apply_gradients
#     grads_and_vars = self._transform_grads_fn(grads_and_vars)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/contrib/estimator/python/estimator/extenders.py", line 134, in clip_grads
#     gradients = clip_ops.clip_by_global_norm(gradients, clip_norm)[0]
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/ops/clip_ops.py", line 271, in clip_by_global_norm
#     "Found Inf or NaN global norm.")
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/ops/numerics.py", line 44, in verify_tensor_all_finite
#     return verify_tensor_all_finite_v2(t, msg, name)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/ops/numerics.py", line 62, in verify_tensor_all_finite_v2
#     verify_input = array_ops.check_numerics(x, message=message)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py", line 919, in check_numerics
#     "CheckNumerics", tensor=tensor, message=message, name=name)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/framework/ops.py", line 3300, in create_op
#     op_def=op_def)
#   File "/home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow/python/framework/ops.py", line 1801, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# InvalidArgumentError (see above for traceback): Found Inf or NaN global norm. : Tensor had Inf values
# 	 [[node linear/head/VerifyFinite/CheckNumerics (defined at /home/luckierdodge/anaconda3/envs/autoperf_tf/lib/python3.7/site-packages/tensorflow_estimator/contrib/estimator/python/estimator/extenders.py:134) ]]
